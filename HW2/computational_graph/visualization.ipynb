# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from config import *

# %%
df_com = pd.read_csv('output/ComGraph_result.csv')
df_com
# Out:
#      train_loss  train_acc  val_loss   val_acc
# 0      4.146678   0.020381  3.912147  0.020000
# 1      3.911050   0.031206  3.912237  0.024444
# 2      3.910068   0.037143  3.912330  0.020000
# 3      3.909092   0.041000  3.912425  0.022222
# 4      3.908121   0.043159  3.912523  0.020000
# ..          ...        ...       ...       ...
# 295    3.772814   0.048968  3.985994  0.020000
# 296    3.772635   0.048968  3.986269  0.020000
# 297    3.772458   0.048968  3.986543  0.020000
# 298    3.772281   0.048968  3.986817  0.020000
# 299    3.772105   0.048968  3.987091  0.020000
#
# [300 rows x 4 columns]

# %%
def plot_loss(df):
    fig, ax = plt.subplots(2, 1, figsize=(8, 6))
    ax[0].plot(df['train_acc'], label='train_acc')
    ax[0].plot(df['val_acc'], label='val_acc')
    ax[0].legend()

    ax[1].plot(df['train_loss'], label='train_loss')
    ax[1].plot(df['val_loss'], label='val_loss')
    ax[1].legend()
    plt.savefig('com_evaluate.png')

plot_loss(df_com.loc[:300])
