# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from config import *

# %%
df_com = pd.read_csv('output/ComGraph_h256_e300_b450.csv')
df_com
# Out:
#      train_loss  train_acc  val_loss   val_acc
# 0      4.147806   0.020095  3.912143  0.022222
# 1      3.910987   0.031651  3.912233  0.017778
# 2      3.910006   0.037048  3.912326  0.015556
# 3      3.909030   0.040063  3.912422  0.017778
# 4      3.908059   0.042159  3.912520  0.020000
# ..          ...        ...       ...       ...
# 295    3.772796   0.048397  3.986015  0.015556
# 296    3.772618   0.048397  3.986290  0.015556
# 297    3.772441   0.048413  3.986564  0.015556
# 298    3.772264   0.048413  3.986838  0.015556
# 299    3.772088   0.048333  3.987112  0.015556
#
# [300 rows x 4 columns]

# %%
def plot_loss(df):
    fig, ax = plt.subplots(2, 1, figsize=(8, 6))
    ax[0].plot(df['train_acc'], label='train_acc')
    ax[0].plot(df['val_acc'], label='val_acc')
    ax[0].legend()

    ax[1].plot(df['train_loss'], label='train_loss')
    ax[1].plot(df['val_loss'], label='val_loss')
    ax[1].legend()
    # plt.savefig('com_evaluate.png')

plot_loss(df_com.loc[:300])
